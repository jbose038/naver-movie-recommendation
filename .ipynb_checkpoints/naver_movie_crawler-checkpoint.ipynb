# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import functools as ft
import numpy as np
import pandas as pd
from time import sleep
import re
from pprint import pprint

# %%
year_max, year_min = 2019,2000
year_pages = []
print('Range : %d ~ %d'%(year_min,year_max))
for info in BeautifulSoup(urlopen('https://movie.naver.com/movie/sdb/browsing/bmovie_open.nhn'),'html.parser').find('table').select('td'):
    if year_min <= int(info.text[:4]) <= year_max:
        year, pages = info.text[:4], str(np.ceil(float(info.text[7:-1])/20).astype(int))
        print('Year '+year+' - '+pages+' pages')
        year_pages.append((year,pages))
year_pages
# Out:
# Range : 2000 ~ 2019
# Year 2019 - 43 pages
# Year 2018 - 50 pages
# Year 2017 - 53 pages
# Year 2016 - 59 pages
# Year 2015 - 71 pages
# Year 2014 - 76 pages
# Year 2013 - 61 pages
# Year 2012 - 44 pages
# Year 2011 - 41 pages
# Year 2010 - 29 pages
# Year 2009 - 24 pages
# Year 2008 - 28 pages
# Year 2007 - 26 pages
# Year 2006 - 24 pages
# Year 2005 - 21 pages
# Year 2004 - 38 pages
# Year 2003 - 20 pages
# Year 2002 - 18 pages
# Year 2001 - 17 pages
# Year 2000 - 19 pages
# [('2019', '43'),
#  ('2018', '50'),
#  ('2017', '53'),
#  ('2016', '59'),
#  ('2015', '71'),
#  ('2014', '76'),
#  ('2013', '61'),
#  ('2012', '44'),
#  ('2011', '41'),
#  ('2010', '29'),
#  ('2009', '24'),
#  ('2008', '28'),
#  ('2007', '26'),
#  ('2006', '24'),
#  ('2005', '21'),
#  ('2004', '38'),
#  ('2003', '20'),
#  ('2002', '18'),
#  ('2001', '17'),
#  ('2000', '19')]

# %%
csvdata = []
for year, pages in year_pages:
    for page in range(1,int(pages)+1):
        try:
            soup = BeautifulSoup(urlopen('https://movie.naver.com/movie/sdb/browsing/bmovie.nhn?open='+year+'&page='+str(page)),'html.parser')
            for link in soup.find('ul','directory_list').select('li>a'):
                date = re.findall('\d{2}.\d{2}',link.text)
                
                if 'href' in link.attrs and 'class' not in link.attrs:
                    basic_page = 'https://movie.naver.com'+link.attrs['href']
                    data = BeautifulSoup(urlopen(basic_page),'html.parser')
                    
                    # title
                    title = data.find('h3','h_movie').select('h3>a')[0].text
                    
                    # date
                    try:
                        date = data.find('dl','info_spec').find('dd').find_all('span')[-1].find_all('a')[-1].text[1:]
                    except:
                        date = ''
                    
                    # rating, vote_count
                    try:
                        rating = str(ft.reduce(lambda x,y:x+y,[val.text for val in data.find('div','score score_left').select('div>a>em')[:4]]))
                        vote_count = data.find('div','score score_left').find('div','ly_count').em.text
                    except:
                        rating = '0.00'
                    # genre
                    genre = '|'.join(list(map(lambda x: x.text, filter(lambda x: 'genre' in x.attrs['href'], data.find('dl','info_spec').select('dd>p>span>a')))))
                    genre = genre.replace('멜로/로맨스','로맨스')
                    
                    detail_page = basic_page.replace('basic','detail')
                    detail_soup = BeautifulSoup(urlopen(detail_page))
                    
                    #plot
                    plot = data.find_all('p','con_tx')[0].text
                    
                    # actors
                    main_act,supp_act = '',''
                    main_num = sum([1 if line.text == '주연' else 0 for line in detail_soup.find_all('em','p_part')])
                    if main_num > 0:
                        for i,actor in enumerate(detail_soup.find('ul','lst_people').find_all('a','k_name')):
                            if i<main_num:
                                main_act += actor.text+'|'
                            else:
                                supp_act += actor.text+'|'
                        main_act,supp_act = main_act[:-1],supp_act[:-1]
                        
                    #img_url
                    try:
                        img_url = data.find('div','poster').find('img').attrs['src']
                    except:
                        img_url = ''
                    
                    # data check => save
                    if rating != '0.00' and genre != '' and len(date) > 0:
                        '''
                        영화제목, 장르, 연도, 날짜, 평점, 투표수, 주연, 조연, url, 이미지링크
                        '''
                        csvdata.append([title, genre, year, date, rating, vote_count,
                                       plot, main_act, supp_act, basic_page,img_url])
            print('year '+year+' page '+str(page)+'/{} - crawling completed'.format(pages))
            #sleep(3)
        except Exception as e:
            print('year '+year+' page '+str(page)+'/{} - crawling failed'.format(pages))
            print('Error at title({}) : '.format(title),str(e))
        if page % 10 == 0:
            print('Check per 10 pages - Recently appended 10 data')
            pprint(csvdata[-10:])

# %%
len(csvdata)

# %%
df = pd.DataFrame(csvdata,columns=['title','genre','year','date','rating','vote_count','plot', 'main_act','supp_act','page_url','img_url'])
df.head()

# %%
df['vote_count'] = df['vote_count'].apply(lambda x: int(x.replace(',','')))

# %%
import datetime
today = datetime.datetime.today()
mmdd = str(today.month) + str(today.day)

df.to_csv('./dataset/naver_movie_dataset_'+mmdd+'.csv',encoding='utf-8',index=False)
del df
# Out:
# '1227'

# %%
df = pd.read_csv('./dataset/naver_movie_dataset_1227.csv')
df.head(20)
# Out:
#                          title      genre  year   date  rating  vote_count  \
# 0                       0.0MHz         공포  2019   5.29    5.01        2016
# 1                          1+3        로맨스  2019  12.12    8.60          15
# 2                     10 미니츠 곤      액션|범죄  2019  11.21    3.40          20
# 3   100일 동안 100가지로 100퍼센트 행복찾기        코미디  2019   9.12    8.88         286
# 4                          10년        드라마  2019  12.12    7.43           7
# 5                      12번째 솔저         전쟁  2019   4.11    9.08         144
# 6                      13년의 공백     드라마|가족  2019   7.04    5.96          47
# 7                     1919 유관순      다큐멘터리  2019   3.14    8.32         359
# 8                2047 버추얼 레볼루션      SF|액션  2019  10.03    4.50           2
# 9                       47미터 2     공포|스릴러  2019   8.28    6.99        2104
# 10              48시간: 지구 최후의 날        코미디  2019   8.01    8.71           7
# 11                        6솔져스      액션|전쟁  2019   5.16    6.14          21
# 12                       7 솔져스  액션|드라마|전쟁  2019   9.19    2.00           1
# 13                    82년생 김지영        드라마  2019  10.23    6.69       46721
# 14            8년 전쟁: 이란 vs 이라크      액션|전쟁  2019   4.25    6.38           8
# 15                   EBS 댄스파티!         가족  2019  10.16    7.33           3
# 16                        가버나움        드라마  2019   1.24    9.59        3044
# 17                   가장 보통의 연애        로맨스  2019  10.02    7.81        7029
# 18                        갈까부다      다큐멘터리  2019   9.01    9.50           8
# 19                     감쪽같은 그녀        드라마  2019  12.04    7.51        1266
#
#                                                  plot  \
# 0   에디슨의 마지막 발명품, 유령 탐지기? “증명할 수 없는 미스터리란 없다” 가지 말...
# 1   멈추지 않는 성욕과 사랑하는 세 명의 남편을 위해,\r 선상에서 밤낮 없이 몸을 파...
# 2   동물적인 직감과 1초의 오차도 용납하지 않는 설계자 ‘렉스’\r 철저한 계획 하에 ...
# 3   어렸을 적부터 함께 자라고, IT 회사도 공동 운영,\r 사는 집도 아랫집, 윗집으...
# 4   안락사, 인공지능과 완전히 통제된 교육,\r 디지털 유산과 알 권리, 환경오염, 전...
# 5   제2차 세계대전 나치에 점령된 노르웨이.\r 나치를 함락시킬 유일한 ‘마틴 레드 작...
# 6   담배를 사러 다녀 오겠다는 아버지는 그렇게 돌아오지 않았다.\r 엄마는 아버지 대신...
# 7   100년 전, 소녀들이 대한독립을 위해 세상에 맞서기 시작했다.\r 우리가 기억해야...
# 8   가상현실 기술의 발달로 환상과 현실이 혼합된 근 미래의 유럽.\r 어느 날, 사이버...
# 9   물에 잠긴 고대 마야의 수중도시 '시발바'를 향해\r 짜릿한 동굴 다이빙에 나선 '...
# 10  어느 날 갑자기 세상이 사라졌다! 하루아침에 모두 붕괴되어 버린 건물들과 사라져버린...
# 11  터키 국경 지역에서 잔악무도한 테러 단체가 판치는 가운데, 알파슬란 대위가 이끄는 ...
# 12  군인들이 어떻게 생활하는지, 그들의 인간적인 모습을 알리고 싶어서 미군부대를 따라 ...
# 13  1982년 봄에 태어나 누군가의 딸이자 아내, 동료이자 엄마로 2019년 오늘을 살...
# 14  8년간 이어진 이란-이라크 전쟁의 영웅 아흐마드 모테바젤. 지휘관이자 혁명가인 그는...
# 15  번개맨, 번개걸, 뿡뿡이, 뿡순이, 뚜앙 등 EBS 캐릭터들이 최초로 한 자리에 총...
# 16  나를 세상에 태어나게 한 \r "부모님을 고소하고 싶어요..."\r -출생기록조차 ...
# 17  전 여친에 상처받은 ‘재훈’(김래원).  여느 때처럼 숙취로 시작한 아침,  모르는...
# 18  43살 영화감독 고봉수는 자신보다 18살 어린 여자친구 최은비를 위해 국악 다큐멘터...
# 19  “초면에 실례하겠습니다~” 72살 나 홀로 라이프를 즐기는 ‘말순’ 할매의 인생에 ...
#
#                                        main_act  \
# 0                           정은지|이성열|최윤영|신주환|정원창
# 1                                          증미혜자
# 2                              브루스 윌리스|마이클 치클리스
# 3                      플로리안 데이비드 핏츠|마치아스 슈와바이어퍼
# 4          스기사키 하나|쿠니무라 준|이케와키 치즈루|타이가|카와구치 사토루
# 5                         토마스 갈라스타드|조나단 리스 마이어스
# 6        타카하시 잇세이|릴리 프랭키|사이토 타쿠미|마츠오카 마유|칸노 미스즈
# 7   이새봄|양윤희|김나니|박자희|김규리|김무늬|류의도|장세아|황도원|문보람|나애진
# 8                          마이크 도퍼드|제인 배들러|요헨 해겔
# 9                소피 넬리스|시스틴 로즈 스탤론|브리안느 쥬|코린 폭스
# 10                                  알렉세이 드미트리에브
# 11                                        케렘 버신
# 12                                       디나 샤하비
# 13                                       정유미|공유
# 14                                     하디 헤자지파르
# 15                  서홍석|정승민|최오식|이상철|노한솔|문지수|전은비
# 16                          자인 알 라피아|요르다노스 시프로우
# 17                                      김래원|공효진
# 18                                  최은비|고봉수|김정기
# 19                                      나문희|김수안
#
#                                              supp_act  \
# 0                                         박명신|남정희|강태웅
# 1                                             진담문|등월평
# 2                                                 NaN
# 3         미리엄 스테인|한넬로르 엘스너|카타리나 탈바흐|요하네스 알마예르|울프강 스텀프
# 4                                                 NaN
# 5                           매즈 소요가드 피터센|마리 블로쿠스|베가 호엘
# 6                 사토 지로|오니시 리쿠|오리모토 준키치|무라카미 준|칸베 히로시
# 7                                                 NaN
# 8      맥시밀리엔 폴레인|니콜라스 반 비버렌|에밀리언 드 팔코|멜리사 마르스|패트라 실랜더
# 9                      브렉 베싱어|다비 산토스|킬린 람보|존 코베트|니아 롱
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13         김미경|공민정|박성연|이봉련|김성철|이얼|김미경|손성찬|강애심|류아영|김정영
# 14                                                NaN
# 15                                                NaN
# 16  보루와티프 트레저 반콜|나딘 라바키|하이타 아이잠|카우사르 알 하다드|파디 유세프|...
# 17                강기영|정웅인|장소연|이채은|정혜린|손우현|박근록|주민경|지일주
# 18                고성완|이주예|주남정|최은애|구웅서|최진욱|김명건|박상준|이경훈
# 19  고규필|임한빈|강보경|진선미|심완준|최정윤|임현성|이용이|이미영|박서진|김서영|권소...
#
#                                              page_url  \
# 0   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 1   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 2   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 3   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 4   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 5   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 6   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 7   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 8   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 9   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 10  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 11  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 12  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 13  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 14  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 15  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 16  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 17  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 18  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 19  https://movie.naver.com/movie/bi/mi/basic.nhn?...
#
#                                               img_url
# 0   https://movie-phinf.pstatic.net/20190517_285/1...
# 1   https://movie-phinf.pstatic.net/20191204_25/15...
# 2   https://movie-phinf.pstatic.net/20191104_204/1...
# 3   https://movie-phinf.pstatic.net/20190823_42/15...
# 4   https://movie-phinf.pstatic.net/20191120_7/157...
# 5   https://movie-phinf.pstatic.net/20190329_230/1...
# 6   https://movie-phinf.pstatic.net/20190529_195/1...
# 7   https://movie-phinf.pstatic.net/20190222_78/15...
# 8   https://movie-phinf.pstatic.net/20190925_8/156...
# 9   https://movie-phinf.pstatic.net/20190828_168/1...
# 10  https://movie-phinf.pstatic.net/20190724_149/1...
# 11  https://movie-phinf.pstatic.net/20190508_297/1...
# 12  https://movie-phinf.pstatic.net/20190923_44/15...
# 13  https://movie-phinf.pstatic.net/20191024_215/1...
# 14  https://movie-phinf.pstatic.net/20190417_262/1...
# 15  https://movie-phinf.pstatic.net/20191106_294/1...
# 16  https://movie-phinf.pstatic.net/20190109_149/1...
# 17  https://movie-phinf.pstatic.net/20190911_29/15...
# 18  https://movie-phinf.pstatic.net/20190422_235/1...
# 19  https://movie-phinf.pstatic.net/20191204_6/157...

# %%
df.shape
# Out:
# (10259, 11)

# %%
c = df['rating'].mean()
m = df['vote_count'].quantile(.6)
print(round(c,3), round(m,3))

def weighted_vote_average(record):
    v, r = record['vote_count'], record['rating']
    return (v/(v+m))*r + (m/(m+v))*c

df['weighted_vote'] = df.apply(weighted_vote_average,axis=1)
# Out:
# 7.187 173.0

# %% [markdown]
# ### 타이틀 검색

# %%
search = '어벤 져스'
df[df['title'].apply(lambda x: x.replace(' ','')).str.startswith(search.replace(' ',''))].sort_values('weighted_vote',ascending=False)
# Out:
#                  title         genre  year   date  rating  vote_count  \
# 430         어벤져스: 엔드게임         액션|SF  2019   4.24    9.38       68905
# 1219      어벤져스: 인피니티 워  액션|모험|판타지|SF  2018   4.25    8.96       35881
# 6423              어벤져스      액션|SF|모험  2012   4.26    8.80       17954
# 3847  어벤져스: 에이지 오브 울트론  액션|모험|판타지|SF  2015   4.23    8.31       31268
# 1218    어벤져스 그림: 시간 전쟁         액션|모험  2018  10.30    5.30          10
# 5724          어벤져스 어셈블         애니메이션  2013   5.26    5.40          15
# 429       어벤져스 오브 저스티스     액션|코미디|가족  2019  10.16    2.80          10
#
#                                                    plot  \
# 430   인피니티 워 이후 절반만 살아남은 지구 마지막 희망이 된 어벤져스 먼저 떠난 그들을...
# 1219  새로운 조합을 이룬 어벤져스,\r 역대 최강 빌런 타노스에 맞서 세계의 운명이 걸린...
# 6423  지구의 안보가 위협당하는 위기의 상황에서 슈퍼히어로들을 불러모아 세상을 구하는, 일...
# 3847  쉴드의 숙적 히드라는 연구를 통해 새로운 능력자 막시모프 남매를 탄생시키고, 히드라...
# 1218  시공간의 균열로 인해 마법 세계와의 통로가 열렸다! 아틀란티스의 여왕 막다는 마법의...
# 5724  세계 최강의 수퍼 히어로가 뭉쳤다. 아이언맨, 헐크, 캡틴 아메리카, 호크아이, 블...
# 429   은하계 최강의 빌런 조크스터는 태양을 없애 지구에 새로운 빙하기를 불러일으키고자 한...
#
#                                                main_act  \
# 430   로버트 다우니 주니어|크리스 에반스|크리스 헴스워스|마크 러팔로|스칼렛 요한슨|제레...
# 1219  로버트 다우니 주니어|조슈 브롤린|크리스 헴스워스|베네딕트 컴버배치|크리스 프랫|마...
# 6423  로버트 다우니 주니어|스칼렛 요한슨|크리스 헴스워스|크리스 에반스|마크 러팔로|제레...
# 3847  로버트 다우니 주니어|크리스 헴스워스|마크 러팔로|크리스 에반스|스칼렛 요한슨|제레...
# 1218                                             로렌 파킨슨
# 5724                                                NaN
# 429   에이미 스마트|토니 차발레로|사이먼 렉스|스티븐 랜나지시|제프 체이스|제이슨 앨런 스미스
#
#                                                supp_act  \
# 430   베네딕트 컴버배치|조 샐다나|크리스 프랫|채드윅 보스만|톰 홀랜드|안소니 마키|기네...
# 1219  세바스찬 스탠|기네스 팰트로|폼 클레멘티에프|레티티아 라이트|카렌 길런|다나이 구리...
# 6423  기네스 팰트로|코비 스멀더스|폴 베타니|클락 그레그|루 페리그노|스텔란 스카스가드|...
# 3847  애런 존슨|엘리자베스 올슨|폴 베타니|코비 스멀더스|스텔란 스카스가드|수현|토마스 ...
# 1218                                                NaN
# 5724                                                NaN
# 429                                                 NaN
#
#                                                page_url  \
# 430   https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 1219  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 6423  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 3847  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 1218  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 5724  https://movie.naver.com/movie/bi/mi/basic.nhn?...
# 429   https://movie.naver.com/movie/bi/mi/basic.nhn?...
#
#                                                 img_url  weighted_vote
# 430   https://movie-phinf.pstatic.net/20190417_250/1...       9.374507
# 1219  https://movie-phinf.pstatic.net/20180322_242/1...       8.951490
# 6423  https://movie-phinf.pstatic.net/20120426_172/1...       8.784602
# 3847  https://movie-phinf.pstatic.net/20150324_33/14...       8.303818
# 1218  https://movie-phinf.pstatic.net/20181102_272/1...       7.083456
# 5724  https://movie-phinf.pstatic.net/20150918_131/1...       7.044003
# 429   https://movie-phinf.pstatic.net/20191022_233/1...       6.946844
